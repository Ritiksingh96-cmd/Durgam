# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as mtl
import seaborn as sns

# %%
df = pd.read_csv("atm_cashout_ieee_ncrp_benchmark.csv")

# %%
df.head()
# Out:
#              timestamp     amount victim_city  mule_latitude  mule_longitude  \
# 0  2026-08-22 14:13:55   46461.79   Delhi NCR      28.610367       77.272456
# 1  2026-08-14 13:22:56   23107.42      Mumbai      19.136144       72.846963
# 2  2026-08-23 04:25:04   54855.48     Jamtara      23.898299       86.787236
# 3  2026-08-20 09:08:20  143678.41     Kolkata      22.580397       88.418383
# 4  2026-08-11 15:31:38   20794.24   Delhi NCR      28.575797       77.275633
#
#    atm_latitude  atm_longitude  distance_to_atm_km  transaction_velocity  \
# 0     28.597591      77.271766               1.420                  1.50
# 1     19.114287      72.861431               2.862                  5.04
# 2     23.904401      86.760240               2.822                  2.87
# 3     22.577984      88.403632               1.535                  6.96
# 4     28.572203      77.280555               0.624                  0.42
#
#    historical_hotspot_score  cashout_atm_label
# ...
